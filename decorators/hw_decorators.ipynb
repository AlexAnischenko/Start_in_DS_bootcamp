# %% [markdown]
# # Домашнее задание: декораторы

# %% [markdown]
# ## Импорт библиотек, установка констант

# %%
import requests
import time
import re
import functools
from random import randint

# %%
BOOK_PATH = 'https://www.gutenberg.org/files/2638/2638-0.txt'

# %% [markdown]
# ## Задание 1

# %%
def benchmark(func):
    """
    Декоратор, выводящий время, которое заняло выполнение декорируемой функции
    """
    def wrapper(*args, **kwargs):
        start = time.perf_counter()
        result = func(*args, **kwargs)
        end = time.perf_counter()
        print(f'Время выполнения функции {func.__name__}: {end - start:.18f}')
        return result

    return wrapper

# %% [markdown]
# ## Задание 2

# %%
def logging(func):
    """
    Декоратор, который выводит параметры с которыми была вызвана функция
    """
    def wrapper(*args, **kwargs):
        result = func(*args, **kwargs)
        args_str = ', '.join(repr(arg) for arg in args)
        print(f'Функция вызвана с параметрами:\n({args_str},), {kwargs}')
        return result

    return wrapper

# %% [markdown]
# ## Задание 3

# %%
def counter(func):
    """
    Декоратор, считающий и выводящий количество вызовов декорируемой функции
    """
    def wrapper(*args, **kwargs):
        wrapper.cnt += 1
        result = func(*args, **kwargs)
        print(f'Функция была вызвана: { wrapper.cnt} раз')
        return result

    wrapper.cnt = 0
    return wrapper

# %% [markdown]
# ## Задание 4

# %%
def memo(func):
  """
  Декоратор, запоминающий результаты исполнения функции func, чьи аргументы args должны быть хешируемыми
  """
  cache = {}

  def fmemo(*args):
    if args not in cache:
        cache[args] = func(*args)
    return cache[args]

  fmemo.cache = cache
  return fmemo

# %% [markdown]
# ## Тестирование

# %%
@counter
@logging
@benchmark
def word_count(word, url=BOOK_PATH):
    """
    Функция для посчета указанного слова на html-странице
    """

    # отправляем запрос в библиотеку Gutenberg и забираем текст
    raw = requests.get(url).text

    # заменяем в тексте все небуквенные символы на пробелы
    processed_book = re.sub('[\W]+' , ' ', raw).lower()

    # считаем
    cnt = len(re.findall(word.lower(), processed_book))

    return f"Cлово {word} встречается {cnt} раз"

print(word_count('whole'))
# Out:
# Время выполнения функции word_count: 0.628290607000053569
# Функция вызвана с параметрами:
# ('whole',), {}
# Функция была вызвана: 1 раз
# Cлово whole встречается 176 раз

# %%
def fib(n):
    if n < 2:
        return n
    return fib(n-2) + fib(n-1)

# %%
# измеряем время выполнения
start = time.time()
fib(35)
end = time.time()
print(f'Время выполнения без декоратора {end - start}')
# Out:
# Время выполнения без декоратора 4.955354928970337

# %%
@memo
def fib(n):
    if n < 2:
        return n
    return fib(n-2) + fib(n-1)

# %%
# измеряем время выполнения
start = time.time()
fib(35)
end = time.time()
print(f'Время выполнения с декоратором {end - start}')
# Out:
# Время выполнения с декоратором 0.00018835067749023438
